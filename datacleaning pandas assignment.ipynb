# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN',
'londON_StockhOlm',

'Budapest_PaRis', 'Brussels_londOn'],
'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )',
'12. Air France', '"Swiss Air"']})

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
df.dtypes
# Out:
# From_To          object
# FlightNumber    float64
# RecentDelays     object
# Airline          object
# dtype: object

# %%
df['FlightNumber'][1]=10055
# Out:
# <ipython-input-4-adc3a1f5bfeb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FlightNumber'][1]=10055

# %%
df['FlightNumber'][3]=10075
# Out:
# <ipython-input-5-690c1141ce8b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FlightNumber'][3]=10075

# %%
df.FlightNumber=df.FlightNumber.astype('int64')

# %%
df.dtypes['FlightNumber']
# Out:
# dtype('int64')

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"

# %%
new=df['From_To'].apply(str).str.split("_",n=1,expand=True)

# %%
new
# Out:
#           0          1
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
df['From']=new[0]

# %%
df['To']=new[1]

# %%
df.drop(columns='From_To',inplace=True)

# %%
df
# Out:
#    FlightNumber  RecentDelays              Airline      From         To
# 0         10045      [23, 47]               KLM(!)    LoNDon      paris
# 1         10055            []    <Air France> (12)    MAdrid      miLAN
# 2         10065  [24, 43, 87]  (British Airways. )    londON  StockhOlm
# 3         10075          [13]       12. Air France  Budapest      PaRis
# 4         10085      [67, 32]          "Swiss Air"  Brussels     londOn

# %%
df['From']=df['From'].apply(str).str.capitalize()

# %%
df['To']=df['To'].apply(str).str.capitalize()

# %%
df
# Out:
#    FlightNumber  RecentDelays              Airline      From         To
# 0         10045      [23, 47]               KLM(!)    London      Paris
# 1         10055            []    <Air France> (12)    Madrid      Milan
# 2         10065  [24, 43, 87]  (British Airways. )    London  Stockholm
# 3         10075          [13]       12. Air France  Budapest      Paris
# 4         10085      [67, 32]          "Swiss Air"  Brussels     London

# %%
split=pd.DataFrame(df['RecentDelays'].tolist(),columns=['delay1', 'delay2', 'delay3'])

# %%
split
# Out:
#    delay1  delay2  delay3
# 0    23.0    47.0     NaN
# 1     NaN     NaN     NaN
# 2    24.0    43.0    87.0
# 3    13.0     NaN     NaN
# 4    67.0    32.0     NaN

# %%
df=pd.concat([df,split],axis=1)

# %%
df.drop(columns='RecentDelays',inplace=True)

# %%
df
# Out:
#    FlightNumber              Airline      From         To  delay1  delay2  \
# 0         10045               KLM(!)    London      Paris    23.0    47.0
# 1         10055    <Air France> (12)    Madrid      Milan     NaN     NaN
# 2         10065  (British Airways. )    London  Stockholm    24.0    43.0
# 3         10075       12. Air France  Budapest      Paris    13.0     NaN
# 4         10085          "Swiss Air"  Brussels     London    67.0    32.0
#
#    delay3
# 0     NaN
# 1     NaN
# 2    87.0
# 3     NaN
# 4     NaN
